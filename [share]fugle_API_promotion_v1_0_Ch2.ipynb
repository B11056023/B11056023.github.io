# %% [markdown]
# <a href="https://colab.research.google.com/github/B11056023/B11056023.github.io/blob/main/%5Bshare%5Dfugle_API_promotion_v1_0_Ch2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Chapter2. 行情 API 實戰

# %%
# 安裝富果行情 API 套件
# !pip install fugle-marketdata==2.1.0 -q

# 安裝 linetool 套件
# !pip install linetool -q
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for linetool (setup.py) ... done

# %% [markdown]
# ## 富果行情 API 功能介紹 - REST API

# %%
# 載入套件
from fugle_marketdata import WebSocketClient, RestClient
import pandas as pd

# %%
# API Key 可至金鑰申請與管理頁的行情 API 區申請：https://developer.fugle.tw/docs/key/
fugle_api_key = "INPUT_YOUR_FUGLE_API_KEY"
client = RestClient(api_key = fugle_api_key)
stock = client.stock  # Stock REST API client

# %% [markdown]
# ### 日內行情（intraday）

# %%
# 取得上市股票列表
stock.intraday.tickers(
    type="EQUITY", # 資料類型，可選 EQUITY 股票；INDEX 指數；ODDLOT 盤中零股
    market="TSE" ,# 市場別，可選 TSE 上市；OTC 上櫃；ESB 興櫃一般板等市場
    industry="01" # 產業別，產業代碼可參考：https://developer.fugle.tw/docs/data/http-api/intraday/tickers#%E7%94%A2%E6%A5%AD%E5%88%A5%E4%BB%A3%E7%A2%BC
    )

# %%
# 取得個股最新交易日的基本資訊
stock.intraday.ticker(symbol='2330')
# Out:
# {'date': '2023-10-25',
#  'type': 'EQUITY',
#  'exchange': 'TWSE',
#  'market': 'TSE',
#  'symbol': '2330',
#  'name': '台積電',
#  'industry': '24',
#  'securityType': '01',
#  'previousClose': 544,
#  'referencePrice': 544,
#  'limitUpPrice': 598,
#  'limitDownPrice': 490,
#  'canDayTrade': True,
#  'canBuyDayTrade': True,
#  'canBelowFlatMarginShortSell': True,
#  'canBelowFlatSBLShortSell': True,
#  'isAttention': False,
#  'isDisposition': False,
#  'isUnusuallyRecommended': False,
#  'isSpecificAbnormally': False,
#  'matchingInterval': 0,
#  'securityStatus': 'NORMAL',
#  'boardLot': 1000,
#  'tradingCurrency': 'TWD'}

# %%
# 取得個股即時報價
stock.intraday.quote(symbol='2330')
# Out:
# {'date': '2023-10-25',
#  'type': 'EQUITY',
#  'exchange': 'TWSE',
#  'market': 'TSE',
#  'symbol': '2330',
#  'name': '台積電',
#  'referencePrice': 544,
#  'previousClose': 544,
#  'openPrice': 544,
#  'openTime': 1698195606026684,
#  'highPrice': 551,
#  'highTime': 1698198695940999,
#  'lowPrice': 544,
#  'lowTime': 1698195606026684,
#  'closePrice': 546,
#  'closeTime': 1698207917959916,
#  'avgPrice': 548.07,
#  'change': 2,
#  'changePercent': 0.37,
#  'amplitude': 1.29,
#  'lastPrice': 546,
#  'lastSize': 2,
#  'bids': [{'price': 546, 'size': 420},
#   {'price': 545, 'size': 429},
#   {'price': 544, 'size': 396},
#   {'price': 543, 'size': 310},
#   {'price': 542, 'size': 340}],
#  'asks': [{'price': 547, 'size': 539},
#   {'price': 548, 'size': 298},
#   {'price': 549, 'size': 324},
#   {'price': 550, 'size': 480},
#   {'price': 551, 'size': 941}],
#  'total': {'tradeValue': 5728478000,
#   'tradeVolume': 10452,
#   'tradeVolumeAtBid': 3931,
#   'tradeVolumeAtAsk': 4987,
#   'transaction': 2498,
#   'time': 1698207917959916},
#  'lastTrade': {'bid': 546,
#   'ask': 547,
#   'price': 546,
#   'size': 2,
#   'time': 1698207917959916,
#   'serial': 5305800},
#  'lastTrial': {'bid': 544,
#   'ask': 545,
#   'price': 544,
#   'size': 1534,
#   'time': 1698195599198592,
#   'serial': 86360},
#  'isContinuous': True,
#  'serial': 5306493,
#  'lastUpdated': 1698207919779028}

# %%
# 取得個股分k資料
stock.intraday.candles(
    symbol='2330',
    timeframe='60' # Ｋ線週期，可選 1 1分Ｋ；5 5分Ｋ；10 10分Ｋ；15 15分Ｋ；30 30分Ｋ；60 60分Ｋ
    )

# %%
# 取得個股逐筆成交明細
stock.intraday.trades(
    symbol='2330',
    limit=500 # 限制筆數，上限 500 筆
    )

# %%
# 取得個股的分價量表
stock.intraday.volumes(symbol='2330')

# %% [markdown]
# ### 行情快照（snapshot）

# %% [markdown]
# 開發者及進階用戶享有此功能！<br>
# 想了解權限，可參考 [v1.0行情方案及資格](https://developer.fugle.tw/docs/pricing/) 頁

# %%
# 取得所有上市市場的股價
snapshot_data = stock.snapshot.quotes(market='TSE')
quotes_data = pd.DataFrame(snapshot_data['data'])
# 篩選出股票列表
quotes_data[quotes_data['type']=='EQUITY'].dropna()
# Out:
#         type symbol      name  openPrice  highPrice  lowPrice  closePrice  \
# 0     EQUITY   0050    元大台灣50     124.20     124.90    124.20      124.20
# 1     EQUITY   0051   元大中型100      68.00      68.65     68.00       68.35
# 2     EQUITY   0052      富邦科技     116.05     116.95    116.05      116.10
# 3     EQUITY   0053      元大電子      67.40      67.40     67.05       67.05
# 4     EQUITY   0055  元大MSCI金融      23.07      23.22     23.07       23.14
# ...      ...    ...       ...        ...        ...       ...         ...
# 1196  EQUITY   9944        新麗      19.55      19.65     19.45       19.60
# 1197  EQUITY   9945       潤泰新      33.65      33.90     33.60       33.80
# 1198  EQUITY   9946      三發地產      17.10      17.20     16.60       17.20
# 1199  EQUITY   9955        佳龍      25.25      26.60     25.25       26.30
# 1200  EQUITY   9958       世紀鋼     173.00     177.00    170.00      170.00
#
#       change  changePercent  tradeVolume  tradeValue   lastUpdated
# 0       0.25           0.20         3951   491586950  1.698212e+15
# 1       0.50           0.74           25     1711450  1.698212e+15
# 2       0.45           0.39           47     5471450  1.698212e+15
# 3       0.60           0.90            4      268550  1.698212e+15
# 4       0.07           0.30           95     2197930  1.698212e+15
# ...      ...            ...          ...         ...           ...
# 1196    0.05           0.26           88     1720250  1.698212e+15
# 1197    0.25           0.75         1023    34526500  1.698212e+15
# 1198    0.10           0.58          791    13414500  1.698212e+15
# 1199    0.15           0.57         2692    70090200  1.698212e+15
# 1200   -2.00          -1.16         4097   709618500  1.698212e+15
#
# [1186 rows x 12 columns]

# %%
# 取得所有上市市場的特定區間漲跌幅列表
movers_list = stock.snapshot.movers(
    market='TSE',
    direction = 'up', # 排序方向，可選 up 由高到低 or down 由低到高
    change='percent', # 可選 percent 漲跌幅 or value 漲跌
    gte = 5,          #大於等於
    lt = 9            #小於
    )
pd.DataFrame(movers_list['data'])
# Out:
#      type symbol   name  openPrice  highPrice  lowPrice  closePrice  change  \
# 0  EQUITY   2543     皇昌      18.15      19.70     17.90       19.35    1.30
# 1  EQUITY   8210     勤誠     197.00     206.50    194.00      199.50   11.50
# 2  EQUITY   6533    晶心科     394.00     412.00    393.00      412.00   23.50
# 3  EQUITY   6719     力智     240.00     255.00    240.00      251.00   13.50
# 4  EQUITY   2388     威盛     119.00     128.50    118.00      124.00    6.50
# 5  EQUITY   2939  凱羿-KY      28.05      29.60     28.05       29.50    1.50
# 6  EQUITY   5258     虹堡     126.00     134.50    124.00      130.50    6.50
# 7  EQUITY   3694     海華      30.30      31.95     30.30       31.80    1.55
#
#    changePercent  tradeVolume  tradeValue       lastUpdated
# 0           7.20         8459   159357300  1698211800000000
# 1           6.12        10708  2153712000  1698211800000000
# 2           6.05         1704   691158500  1698211800000000
# 3           5.68         2252   564210500  1698211800000000
# 4           5.53        41908  5195837500  1698211800000000
# 5           5.36          100     2914050  1698211800000000
# 6           5.24        23274  3012208500  1698211800000000
# 7           5.12         1589    49967450  1698211800000000

# %%
# 取得所有上櫃市場的成交量排行
actives_list = stock.snapshot.actives(
    market='OTC',
    trade='volume'
    )

# 取成交量前 100 的股票列表
pd.DataFrame(actives_list['data'][:100])
# Out:
#       type  symbol     name  openPrice  highPrice  lowPrice  closePrice  \
# 0   EQUITY    4908       前鼎     103.50     105.00     97.50       98.30
# 1   EQUITY  00687B  國泰20年美債      28.63      28.66     28.52       28.55
# 2   EQUITY    1815       富喬      16.00      17.50     15.90       17.00
# 3   EQUITY  00679B  元大美債20年      28.00      28.03     27.91       27.93
# 4   EQUITY    3078       僑威      85.50      87.00     83.50       83.50
# ..     ...     ...      ...        ...        ...       ...         ...
# 95  EQUITY    6147       頎邦      69.50      69.90     68.90       68.90
# 96  EQUITY    6530       創威      56.00      56.60     54.50       55.10
# 97  EQUITY    3169       亞信     120.50     128.00    119.50      127.50
# 98  EQUITY    3491      昇達科     171.50     173.50    168.50      168.50
# 99  EQUITY    6188       廣明      73.80      74.80     73.50       74.40
#
#     change  changePercent  tradeVolume  tradeValue       lastUpdated
# 0    -0.70          -0.71        29834  3027232600  1698211800000000
# 1     0.19           0.67        27785   794606590  1698211800000000
# 2     1.00           6.25        26666   448847600  1698211800000000
# 3     0.18           0.65        21208   593409640  1698211800000000
# 4    -1.80          -2.11        21005  1788196200  1698211800000000
# ..     ...            ...          ...         ...               ...
# 95   -0.30          -0.43         2223   153906600  1698211800000000
# 96   -1.90          -3.33         2046   113329300  1698211800000000
# 97    8.50           7.14         2010   253043000  1698211800000000
# 98   -3.00          -1.75         2000   340786000  1698211800000000
# 99    0.90           1.22         1972   146337100  1698211800000000
#
# [100 rows x 12 columns]

# %% [markdown]
# ### 歷史行情（historical）

# %%
history_options = {
    "symbol": "2330",
    "from": "2023-01-01",
    "to": "2023-11-31",
    "timeframe":"D",
    "fields":"open,high,low,close,volume,change,turnover"
    }

pd.DataFrame(stock.historical.candles(**history_options)['data'])
# Out:
#            date   open   high    low  close    volume  change     turnover
# 0    2023-10-25  544.0  551.0  544.0  544.0  16727199     0.0   9147762904
# 1    2023-10-24  543.0  546.0  540.0  544.0  15761516     0.0   8562488660
# 2    2023-10-23  552.0  553.0  543.0  544.0  24172637   -12.0  13193058890
# 3    2023-10-20  549.0  556.0  546.0  556.0  49143932    10.0  27116129760
# 4    2023-10-19  540.0  548.0  540.0  546.0  26999255     6.0  14717458172
# ..          ...    ...    ...    ...    ...       ...     ...          ...
# 187  2023-01-09  468.0  481.0  467.5  481.0  49186355    22.5  23352375299
# 188  2023-01-06  455.0  459.5  455.0  458.5  21313593     0.0   9745142549
# 189  2023-01-05  459.0  459.5  455.0  458.5  23972099     9.0  10972616269
# 190  2023-01-04  449.5  455.0  448.5  449.5  20626874    -3.5   9310050329
# 191  2023-01-03  446.0  453.5  443.0  453.0  15311364     4.5   6871973708
#
# [192 rows x 8 columns]

# %%
stock.historical.stats(
    symbol='2330'
    )
# Out:
# {'date': '2023-10-25',
#  'type': 'EQUITY',
#  'exchange': 'TWSE',
#  'market': 'TSE',
#  'symbol': '2330',
#  'name': '台積電',
#  'openPrice': 544,
#  'highPrice': 551,
#  'lowPrice': 544,
#  'closePrice': 544,
#  'change': 0,
#  'changePercent': 0,
#  'tradeVolume': 16727199,
#  'tradeValue': 9147762904,
#  'previousClose': 544,
#  'week52High': 594,
#  'week52Low': 370}

# %% [markdown]
# ## 富果行情 API 功能介紹 - WebSocket

# %%
data_list = [] # 可新增一個 list 方便後續觀察資料

# %%
# 取得台積電行情成交價量資訊
from fugle_marketdata import WebSocketClient

def handle_message(message):
    print(message)
    data_list.append(message)

def main():
    client = WebSocketClient(api_key=fugle_api_key) # key 的部分請使用自己的 API KEY
    stock = client.stock
    stock.on('message', handle_message)
    stock.connect()

    stock.subscribe({
        'channel': 'trades',
        'symbol': '2330' # 若要使用多檔股票可改用 symbols 參數
    })

if __name__ == '__main__':
    main()

# %%
data_list

# %% [markdown]
# ## 實戰演練

# %%
# 載入套件
import json
import asyncio
import lineTool

# %%
line_token = "INPUT_YOUR_LINE_TOKEN" # 可至 https://notify-bot.line.me/my/ 取得自己的 line token
# fugle_api_key = "INPUT_YOUR_FUGLE_API_KEY" # 可至 https://developer.fugle.tw/docs/key/ 取得自己的富果 API Key

# %% [markdown]
# ### 使用行情快照（snapshot）取得熱門個股

# %% [markdown]
# 取當日成交量上市前 5 大的股票 <br>
# 單量超過 20 張，就進行 line notify 通知

# %%
# # 取當日成交量上市前 5 大的股票列表
symbol_list = list(map(lambda x:x['symbol'], stock.snapshot.actives(market='TSE', trade='volume')['data'][:5]))

# 訂定單量
size_limit = 20

# %%
class StockNotifier:
    def __init__(self, api_key, line_token, symbol_list, size_limit):
        self.api_key = api_key
        self.line_token = line_token
        self.symbol_list = symbol_list
        self.size_limit = size_limit
        self.client = None

    def _on_new_price(self, message):

        print(message)
        json_data = json.loads(message)

        if json_data['event']=="data" and json_data.get('data',{}).get('isTrial') == None: # 避免用到試撮資料

            # 取最新成交價
            latest_price = json_data['data']['price']
            # 取最新單量
            size = json_data['data']['size']
            # 取最新總量
            volume = json_data['data']['volume']

            symbol = json_data['data']['symbol']

            # 如果最新單量超過訂定的單量張數，就進行 line notify 通知！
            if size > self.size_limit:

                # 預計回傳 line notify 通知的訊息
                msg = f'\n{symbol} 單量超過 {str(self.size_limit)} 張！\n最新價格 {str(latest_price)} 元\n單量 {str(size)} 張\n總量 {str(volume)} 張\n快到 https://www.fugle.tw/ai/{symbol} 查查！ '

                # 執行 line notify 通知
                lineTool.lineNotify(self.line_token, msg)

        # 盤後測試可以加上以下判斷
        elif json_data['event']=="snapshot":

            # 取最新成交價
            latest_price = json_data['data']['price']
            # 取最新單量
            size = json_data['data']['size']
            # 取最新總量
            volume = json_data['data']['volume']

            symbol = json_data['data']['symbol']

            # 如果最新單量超過訂定的單量張數，就進行 line notify 通知！
            if size > self.size_limit:

                # 預計回傳 line notify 通知的訊息
                msg = f'\n{symbol} 單量超過 {str(self.size_limit)} 張！\n最新價格 {str(latest_price)} 元\n單量 {str(size)} 張\n總量 {str(volume)} 張\n快到 https://www.fugle.tw/ai/{symbol} 查查！ '

                # 執行 line notify 通知
                lineTool.lineNotify(self.line_token, msg)


    def handle_connect(self):
        print('connected')

    def handle_disconnect(self, code, message):
        print(f'disconnect: {code}, {message}')

    def handle_error(self, error):
        print(f'error: {error}')

    def main(self):
        self.client = WebSocketClient(api_key=self.api_key)
        stock = self.client.stock
        stock.on('message', self._on_new_price)
        stock.on("connect", self.handle_connect)
        stock.on("disconnect", self.handle_disconnect)
        stock.on("error", self.handle_error)

        stock.connect()

        stock.subscribe({
            'channel': 'trades',
            'symbols': self.symbol_list
        })

if __name__ == '__main__':
    notifier = StockNotifier(api_key=fugle_api_key, line_token=line_token, symbol_list=symbol_list, size_limit=size_limit)
    notifier.main()

# %% [markdown]
# 若遇到 disconnect: 1001, Maximum number of connections reached
# 主要是因為目前提供的方案，能建立一個連線及訂閱五檔股票，若超過連線數就會產生以上錯訊
# 可以到「執行階段」tab 點選重新啟動執行，來清除連線數

# %% [markdown]
# ### 尚未有行情快照（snapshot）權限可使用 tickers api 來練習

# %% [markdown]
# 若沒有開發者權限可改採用其他取得清單的方式，例如：<br>
# 取當日注意股的股票清單（最多五檔）<br>
# 單量超過 20 張，就進行 line notify 通知

# %%
## 實戰演練四 - 取當日注意股的股票清單
attention_list = stock.intraday.tickers(
    type="EQUITY", # 資料類型，可選 EQUITY 股票；INDEX 指數；ODDLOT 盤中零股
    market="TSE" ,# 市場別，可選 TSE 上市；OTC 上櫃；ESB 興櫃一般板等市場
    isAttention=True
    )

symbol_list =list(map(lambda x:x['symbol'], attention_list['data'][:5]))

# 訂定單量
size_limit = 20

# %%
class StockNotifier:
    def __init__(self, api_key, line_token, symbol_list, size_limit):
        self.api_key = api_key
        self.line_token = line_token
        self.symbol_list = symbol_list
        self.size_limit = size_limit
        self.client = None

    def _on_new_price(self, message):
        json_data = json.loads(message)

        if json_data['event']=="data" and json_data.get('data',{}).get('isTrial') == None: # 避免用到試撮資料

            # 取最新成交價
            latest_price = json_data['data']['price']
            # 取最新單量
            size = json_data['data']['size']
            # 取最新總量
            volume = json_data['data']['volume']

            symbol = json_data['data']['symbol']

            # 如果最新單量超過訂定的單量張數，就進行 line notify 通知！
            if size > self.size_limit:

                # 預計回傳 line notify 通知的訊息
                msg = f'\n{symbol} 單量超過 {str(self.size_limit)} 張！\n最新價格 {str(latest_price)} 元\n單量 {str(size)} 張\n總量 {str(volume)} 張\n快到 https://www.fugle.tw/ai/{symbol} 查查！ '

                # 執行 line notify 通知
                lineTool.lineNotify(self.line_token, msg)

        # 盤後測試可以加上以下判斷
        elif json_data['event']=="snapshot":

            # 取最新成交價
            latest_price = json_data['data']['price']
            # 取最新單量
            size = json_data['data']['size']
            # 取最新總量
            volume = json_data['data']['volume']

            symbol = json_data['data']['symbol']

            # 如果最新單量超過訂定的單量張數，就進行 line notify 通知！
            if size > self.size_limit:

                # 預計回傳 line notify 通知的訊息
                msg = f'\n{symbol} 單量超過 {str(self.size_limit)} 張！\n最新價格 {str(latest_price)} 元\n單量 {str(size)} 張\n總量 {str(volume)} 張\n快到 https://www.fugle.tw/ai/{symbol} 查查！ '

                # 執行 line notify 通知
                lineTool.lineNotify(self.line_token, msg)


    def handle_connect(self):
        print('connected')

    def handle_disconnect(self, code, message):
        print(f'disconnect: {code}, {message}')

    def handle_error(self, error):
        print(f'error: {error}')

    def main(self):
        self.client = WebSocketClient(api_key=self.api_key)
        stock = self.client.stock
        stock.on('message', self._on_new_price)
        stock.on("connect", self.handle_connect)
        stock.on("disconnect", self.handle_disconnect)
        stock.on("error", self.handle_error)

        stock.connect()

        stock.subscribe({
            'channel': 'trades',
            'symbols': self.symbol_list
        })

if __name__ == '__main__':
    notifier = StockNotifier(api_key=fugle_api_key, line_token=line_token, symbol_list=symbol_list, size_limit=size_limit)
    notifier.main()

# %% [markdown]
# # 實戰小測驗

# %% [markdown]
# ## 測驗二 - 取得 2330 台積電當日完整的成交明細

# %% [markdown]
# ## 測驗三 - 取當日注意股的股票清單（最多五檔），當單筆家交額超過 500 萬時，就進行 line notify 通知
